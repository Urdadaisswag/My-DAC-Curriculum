# %%
# Import our libraries
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import r2_score
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
from sklearn import tree
import seaborn as sns
import re

# %%
df = pd.read_csv('Data/Salary_Prediction.csv')
df.shape
# Out:
# (742, 33)

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# Job Title             object
# Salary Estimate       object
# Job Description       object
# Rating               float64
# Company Name          object
# Location              object
# Headquarters          object
# Size                  object
# Founded                int64
# Type of ownership     object
# Industry              object
# Sector                object
# Revenue               object
# Competitors           object
# hourly                 int64
# employer_provided      int64
# min_salary             int64
# max_salary             int64
# avg_salary           float64
# company_txt           object
# job_state             object
# same_state             int64
# age                    int64
# python_yn              int64
# R_yn                   int64
# spark                  int64
# aws                    int64
# excel                  int64
# job_simp              object
# seniority             object
# desc_len               int64
# num_comp               int64
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 737         737           Sr Scientist, Immuno-Oncology - Oncology
# 738         738                               Senior Data Engineer
# 739         739  Project Scientist - Auton Lab, Robotics Institute
# 740         740                               Data Science Manager
# 741         741          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 737  $58K-$111K (Glassdoor est.)
# 738  $72K-$133K (Glassdoor est.)
# 739   $56K-$91K (Glassdoor est.)
# 740  $95K-$160K (Glassdoor est.)
# 741  $61K-$126K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 0    Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1    What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2    KnowBe4, Inc. is a high growth information sec...     4.8
# 3    *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4    Data Scientist\nAffinity Solutions / Marketing...     2.9
# ..                                                 ...     ...
# 737  Site Name: USA - Massachusetts - Cambridge\nPo...     3.9
# 738  THE CHALLENGE\nEventbrite has a world-class da...     4.4
# 739  The Auton Lab at Carnegie Mellon University is...     2.6
# 740  Data Science ManagerResponsibilities:\n\nOvers...     3.2
# 741  Returning Candidate? Log back in to the Career...     3.6
#
#                                    Company Name         Location  \
# 0                        Tecolote Research\n3.8  Albuquerque, NM
# 1    University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                  KnowBe4\n4.8   Clearwater, FL
# 3                                     PNNL\n3.8     Richland, WA
# 4                       Affinity Solutions\n2.9     New York, NY
# ..                                          ...              ...
# 737                                    GSK\n3.9    Cambridge, MA
# 738                             Eventbrite\n4.4    Nashville, TN
# 739         Software Engineering Institute\n2.6   Pittsburgh, PA
# 740                           Numeric, LLC\n3.2    Allentown, PA
# 741           Riverside Research Institute\n3.6  Beavercreek, OH
#
#                   Headquarters                    Size  Founded  ...  age  \
# 0                   Goleta, CA   501 to 1000 employees     1973  ...   47
# 1                Baltimore, MD        10000+ employees     1984  ...   36
# 2               Clearwater, FL   501 to 1000 employees     2010  ...   10
# 3                 Richland, WA  1001 to 5000 employees     1965  ...   55
# 4                 New York, NY     51 to 200 employees     1998  ...   22
# ..                         ...                     ...      ...  ...  ...
# 737  Brentford, United Kingdom        10000+ employees     1830  ...  190
# 738          San Francisco, CA  1001 to 5000 employees     2006  ...   14
# 739             Pittsburgh, PA   501 to 1000 employees     1984  ...   36
# 740            Chadds Ford, PA       1 to 50 employees       -1  ...   -1
# 741              Arlington, VA   501 to 1000 employees     1967  ...   53
#
#     python_yn R_yn spark aws  excel        job_simp  seniority  desc_len  \
# 0           1    0     0   0      1  data scientist         na      2536
# 1           1    0     0   0      0  data scientist         na      4783
# 2           1    0     1   0      1  data scientist         na      3461
# 3           1    0     0   0      0  data scientist         na      3883
# 4           1    0     0   0      1  data scientist         na      2728
# ..        ...  ...   ...  ..    ...             ...        ...       ...
# 737         0    0     0   1      0              na     senior      6162
# 738         1    0     1   1      0   data engineer     senior      6130
# 739         0    0     0   0      1              na         na      3078
# 740         0    0     0   0      1         manager         na      1642
# 741         1    0     0   0      0              na         na      3673
#
#      num_comp
# 0           0
# 1           0
# 2           0
# 3           3
# 4           3
# ..        ...
# 737         3
# 738         3
# 739         0
# 740         0
# 741         0
#
# [742 rows x 33 columns]>

# %%
df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         742 non-null    int64
#  1   Job Title          742 non-null    object
#  2   Salary Estimate    742 non-null    object
#  3   Job Description    742 non-null    object
#  4   Rating             742 non-null    float64
#  5   Company Name       742 non-null    object
#  6   Location           742 non-null    object
#  7   Headquarters       742 non-null    object
#  8   Size               742 non-null    object
#  9   Founded            742 non-null    int64
#  10  Type of ownership  742 non-null    object
#  11  Industry           742 non-null    object
#  12  Sector             742 non-null    object
#  13  Revenue            742 non-null    object
#  14  Competitors        742 non-null    object
#  15  hourly             742 non-null    int64
#  16  employer_provided  742 non-null    int64
#  17  min_salary         742 non-null    int64
#  18  max_salary         742 non-null    int64
#  19  avg_salary         742 non-null    float64
#  20  company_txt        742 non-null    object
#  21  job_state          742 non-null    object
#  22  same_state         742 non-null    int64
#  23  age                742 non-null    int64
#  24  python_yn          742 non-null    int64
#  25  R_yn               742 non-null    int64
#  26  spark              742 non-null    int64
#  27  aws                742 non-null    int64
#  28  excel              742 non-null    int64
#  29  job_simp           742 non-null    object
#  30  seniority          742 non-null    object
#  31  desc_len           742 non-null    int64
#  32  num_comp           742 non-null    int64
# dtypes: float64(2), int64(15), object(16)
# memory usage: 191.4+ KB

# %%
# Displaying a STATISTICAL summary of our data in 5dp 
# (only for columns with numerical values)
pd.options.display.float_format = '{:.5f}'.format
df.describe()
# .describe() is a function in pandas that shows the statistical summary of our dataset
# Out:
#        Unnamed: 0    Rating    Founded    hourly  employer_provided  \
# count   742.00000 742.00000  742.00000 742.00000          742.00000
# mean    370.50000   3.61887 1837.15499   0.03235            0.02291
# std     214.34124   0.80121  497.18376   0.17703            0.14972
# min       0.00000  -1.00000   -1.00000   0.00000            0.00000
# 25%     185.25000   3.30000 1939.00000   0.00000            0.00000
# 50%     370.50000   3.70000 1988.00000   0.00000            0.00000
# 75%     555.75000   4.00000 2007.00000   0.00000            0.00000
# max     741.00000   5.00000 2019.00000   1.00000            1.00000
#
#        min_salary  max_salary  avg_salary  same_state       age  python_yn  \
# count   742.00000   742.00000   742.00000   742.00000 742.00000  742.00000
# mean     74.71968   128.14960   100.62601     0.55795  46.59164    0.52830
# std      30.98059    45.22032    38.85595     0.49697  53.77882    0.49954
# min      15.00000    16.00000    13.50000     0.00000  -1.00000    0.00000
# 25%      52.00000    96.00000    73.50000     0.00000  11.00000    0.00000
# 50%      69.50000   124.00000    97.50000     1.00000  24.00000    1.00000
# 75%      91.00000   155.00000   122.50000     1.00000  59.00000    1.00000
# max     202.00000   306.00000   254.00000     1.00000 276.00000    1.00000
#
#            R_yn     spark       aws     excel    desc_len  num_comp
# count 742.00000 742.00000 742.00000 742.00000   742.00000 742.00000
# mean    0.00270   0.22507   0.23720   0.52291  3869.54582   1.05391
# std     0.05188   0.41791   0.42565   0.49981  1521.49587   1.38424
# min     0.00000   0.00000   0.00000   0.00000   407.00000   0.00000
# 25%     0.00000   0.00000   0.00000   0.00000  2801.00000   0.00000
# 50%     0.00000   0.00000   0.00000   1.00000  3731.00000   0.00000
# 75%     0.00000   0.00000   0.00000   1.00000  4740.00000   3.00000
# max     1.00000   1.00000   1.00000   1.00000 10051.00000   4.00000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         0
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# hourly               0
# employer_provided    0
# min_salary           0
# max_salary           0
# avg_salary           0
# company_txt          0
# job_state            0
# same_state           0
# age                  0
# python_yn            0
# R_yn                 0
# spark                0
# aws                  0
# excel                0
# job_simp             0
# seniority            0
# desc_len             0
# num_comp             0
# dtype: int64

# %%
print(df.head())
# Out:
#    Unnamed: 0                  Job Title              Salary Estimate  \
# 0           0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1           1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2           2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3           3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4           4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu... 3.80000
# 1  What You Will Do:\n\nI. General Summary\n\nThe... 3.40000
# 2  KnowBe4, Inc. is a high growth information sec... 4.80000
# 3  *Organization and Job ID**\nJob ID: 310709\n\n... 3.80000
# 4  Data Scientist\nAffinity Solutions / Marketing... 2.90000
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                KnowBe4\n4.8   Clearwater, FL
# 3                                   PNNL\n3.8     Richland, WA
# 4                     Affinity Solutions\n2.9     New York, NY
#
#      Headquarters                    Size  Founded  ... age python_yn R_yn  \
# 0      Goleta, CA   501 to 1000 employees     1973  ...  47         1    0
# 1   Baltimore, MD        10000+ employees     1984  ...  36         1    0
# 2  Clearwater, FL   501 to 1000 employees     2010  ...  10         1    0
# 3    Richland, WA  1001 to 5000 employees     1965  ...  55         1    0
# 4    New York, NY     51 to 200 employees     1998  ...  22         1    0
#
#   spark aws  excel        job_simp  seniority  desc_len  num_comp
# 0     0   0      1  data scientist         na      2536         0
# 1     0   0      0  data scientist         na      4783         0
# 2     1   0      1  data scientist         na      3461         0
# 3     0   0      0  data scientist         na      3883         3
# 4     0   0      1  data scientist         na      2728         3
#
# [5 rows x 33 columns]

# %%
print(df['Salary Estimate'].dtype)
print(df['Salary Estimate'].head())
print(df['Salary Estimate'].unique())
# Out:
# object
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# Name: Salary Estimate, dtype: object
# ['$53K-$91K (Glassdoor est.)' '$63K-$112K (Glassdoor est.)'
#  '$80K-$90K (Glassdoor est.)' '$56K-$97K (Glassdoor est.)'
#  '$86K-$143K (Glassdoor est.)' '$71K-$119K (Glassdoor est.)'
#  '$54K-$93K (Glassdoor est.)' '$86K-$142K (Glassdoor est.)'
#  '$38K-$84K (Glassdoor est.)' '$120K-$160K (Glassdoor est.)'
#  '$126K-$201K (Glassdoor est.)' '$64K-$106K (Glassdoor est.)'
#  '$106K-$172K (Glassdoor est.)' '$46K-$85K (Glassdoor est.)'
#  '$83K-$144K (Glassdoor est.)' '$102K-$190K (Glassdoor est.)'
#  '$67K-$137K (Glassdoor est.)' '$118K-$189K (Glassdoor est.)'
#  '$110K-$175K (Glassdoor est.)' '$64K-$111K (Glassdoor est.)'
#  '$81K-$130K (Glassdoor est.)' '$73K-$119K (Glassdoor est.)'
#  '$86K-$139K (Glassdoor est.)' '$63K-$105K (Glassdoor est.)'
#  '$109K-$177K (Glassdoor est.)' '$63K-$110K (Glassdoor est.)'
#  '$75K-$124K (Glassdoor est.)' '$34K-$61K (Glassdoor est.)'
#  '$72K-$120K (Glassdoor est.)' '$93K-$149K (Glassdoor est.)'
#  '$85K-$140K (Glassdoor est.)' '$77K-$135K (Glassdoor est.)'
#  '$82K-$132K (Glassdoor est.)' '$83K-$137K (Glassdoor est.)'
#  '$115K-$180K (Glassdoor est.)' '$74K-$138K (Glassdoor est.)'
#  '$64K-$112K (Glassdoor est.)' '$68K-$129K (Glassdoor est.)'
#  '$52K-$113K (Glassdoor est.)' '$110K-$150K(Employer est.)'
#  'Employer Provided Salary:$150K-$160K' '$158K-$211K (Glassdoor est.)'
#  '$20K-$39K (Glassdoor est.)' '$56K-$117K (Glassdoor est.)'
#  '$63K-$99K (Glassdoor est.)' '$68K-$114K (Glassdoor est.)'
#  '$41K-$95K (Glassdoor est.)' '$86K-$144K (Glassdoor est.)'
#  '$80K-$139K (Glassdoor est.)' '$56K-$95K (Glassdoor est.)'
#  '$120K-$189K (Glassdoor est.)' '$111K-$176K (Glassdoor est.)'
#  '$84K-$146K (Glassdoor est.)' '$107K-$172K (Glassdoor est.)'
#  '$49K-$85K (Glassdoor est.)' '$61K-$109K (Glassdoor est.)'
#  '$88K-$148K (Glassdoor est.)' '$60K-$99K (Glassdoor est.)'
#  '$41K-$72K (Glassdoor est.)' '$96K-$161K (Glassdoor est.)'
#  '$65K-$130K (Glassdoor est.)' '$52K-$81K (Glassdoor est.)'
#  '$139K-$220K (Glassdoor est.)' '$50K-$102K (Glassdoor est.)'
#  '$85K-$139K (Glassdoor est.)' '$74K-$122K (Glassdoor est.)'
#  '$99K-$157K (Glassdoor est.)' '$79K-$222K (Glassdoor est.)'
#  '$57K-$118K (Glassdoor est.)' '$86K-$141K (Glassdoor est.)'
#  '$94K-$154K (Glassdoor est.)' '$37K-$76K (Glassdoor est.)'
#  '$100K-$160K (Glassdoor est.)' '$55K-$100K (Glassdoor est.)'
#  '$60K-$114K (Glassdoor est.)' '$39K-$68K (Glassdoor est.)'
#  '$64K-$107K (Glassdoor est.)' '$31K-$65K (Glassdoor est.)'
#  '$34K-$62K (Glassdoor est.)' '$117K-$231K (Glassdoor est.)'
#  '$79K-$134K (Glassdoor est.)' '$52K-$93K (Glassdoor est.)'
#  '$55K-$116K (Glassdoor est.)' '$72K-$123K (Glassdoor est.)'
#  '$74K-$124K (Glassdoor est.)' '$40K-$73K (Glassdoor est.)'
#  '$102K-$164K (Glassdoor est.)' '$89K-$153K (Glassdoor est.)'
#  '$61K-$110K (Glassdoor est.)' '$65K-$110K (Glassdoor est.)'
#  '$200K-$275K(Employer est.)' '$68K-$123K (Glassdoor est.)'
#  '$80K-$129K (Glassdoor est.)' '$39K-$71K (Glassdoor est.)'
#  '$38K-$85K (Glassdoor est.)' '$121K-$193K (Glassdoor est.)'
#  '$54K-$102K (Glassdoor est.)' '$102K-$163K (Glassdoor est.)'
#  '$76K-$140K (Glassdoor est.)' '$60K-$101K (Glassdoor est.)'
#  '$82K-$133K (Glassdoor est.)' '$65K-$125K (Glassdoor est.)'
#  '$91K-$148K (Glassdoor est.)' '$95K-$173K (Glassdoor est.)'
#  '$77K-$124K (Glassdoor est.)' '$80K-$135K (Glassdoor est.)'
#  '$85K-$159K (Glassdoor est.)' '$80K-$105K(Employer est.)'
#  '$43K-$81K (Glassdoor est.)' '$29K-$50K (Glassdoor est.)'
#  '$26K-$55K (Glassdoor est.)' '$61K-$118K (Glassdoor est.)'
#  '$60K-$102K (Glassdoor est.)' '$112K-$182K (Glassdoor est.)'
#  '$51K-$112K (Glassdoor est.)' '$113K-$223K (Glassdoor est.)'
#  '$72K-$129K (Glassdoor est.)' '$71K-$123K (Glassdoor est.)'
#  'Employer Provided Salary:$120K-$145K' '$80K-$120K (Glassdoor est.)'
#  '$80K-$130K (Glassdoor est.)' '$59K-$115K (Glassdoor est.)'
#  '$71K-$136K (Glassdoor est.)' '$81K-$167K (Glassdoor est.)'
#  '$71K-$204K (Glassdoor est.)' '$75K-$125K (Glassdoor est.)'
#  '$77K-$136K (Glassdoor est.)' '$74K-$123K (Glassdoor est.)'
#  '$44K-$78K (Glassdoor est.)' '$65K-$148K (Glassdoor est.)'
#  '$59K-$110K (Glassdoor est.)' '$85K-$134K (Glassdoor est.)'
#  '$124K-$204K (Glassdoor est.)' '$131K-$207K (Glassdoor est.)'
#  '$110K-$174K (Glassdoor est.)' '$52K-$101K (Glassdoor est.)'
#  '$81K-$133K (Glassdoor est.)' '$132K-$211K (Glassdoor est.)'
#  '$74K-$140K (Glassdoor est.)' '$100K-$190K (Glassdoor est.)'
#  '$43K-$80K (Glassdoor est.)' '$17-$24 Per Hour(Glassdoor est.)'
#  '$91K-$149K (Glassdoor est.)' '$42K-$82K (Glassdoor est.)'
#  '$116K-$185K (Glassdoor est.)' '$59K-$116K (Glassdoor est.)'
#  '$48K-$95K (Glassdoor est.)' '$31K-$72K (Glassdoor est.)'
#  '$105K-$198K (Glassdoor est.)' '$98K-$182K (Glassdoor est.)'
#  '$73K-$124K (Glassdoor est.)' 'Employer Provided Salary:$200K-$250K'
#  '$21-$34 Per Hour(Glassdoor est.)' '$117K-$206K (Glassdoor est.)'
#  '$111K-$183K (Glassdoor est.)' '$81K-$159K (Glassdoor est.)'
#  '$83K-$166K (Glassdoor est.)' '$114K-$182K (Glassdoor est.)'
#  '$42K-$76K (Glassdoor est.)' '$114K-$179K (Glassdoor est.)'
#  '$60K-$123K (Glassdoor est.)' '$100K-$166K (Glassdoor est.)'
#  '$108K-$173K (Glassdoor est.)' '$48K-$93K (Glassdoor est.)'
#  '$54K-$115K (Glassdoor est.)' '$60K-$127K (Glassdoor est.)'
#  '$90K-$179K (Glassdoor est.)' '$138K-$224K (Glassdoor est.)'
#  '$190K-$220K(Employer est.)' '$35K-$62K (Glassdoor est.)'
#  '$18-$25 Per Hour(Glassdoor est.)' '$39K-$66K (Glassdoor est.)'
#  '$42K-$86K (Glassdoor est.)' '$69K-$127K (Glassdoor est.)'
#  '$40K-$68K (Glassdoor est.)' '$49K-$113K (Glassdoor est.)'
#  '$75K-$140K (Glassdoor est.)' '$66K-$112K (Glassdoor est.)'
#  '$76K-$125K (Glassdoor est.)' '$44K-$86K (Glassdoor est.)'
#  '$15-$25 Per Hour(Glassdoor est.)' '$53K-$92K (Glassdoor est.)'
#  '$65K-$120K (Glassdoor est.)' '$60K-$103K (Glassdoor est.)'
#  '$53K-$105K (Glassdoor est.)' '$33K-$62K (Glassdoor est.)'
#  '$48K-$90K (Glassdoor est.)' '$34K-$64K (Glassdoor est.)'
#  '$66K-$111K (Glassdoor est.)' '$91K-$138K (Glassdoor est.)'
#  '$62K-$114K (Glassdoor est.)' '$71K-$129K (Glassdoor est.)'
#  '$74K-$119K (Glassdoor est.)' '$55K-$97K (Glassdoor est.)'
#  '$15K-$16K(Employer est.)' '$61K-$106K (Glassdoor est.)'
#  '$127K-$199K (Glassdoor est.)' '$74K-$126K (Glassdoor est.)'
#  '$33K-$72K (Glassdoor est.)' '$37K-$63K (Glassdoor est.)'
#  '$67K-$119K (Glassdoor est.)' '$72K-$117K (Glassdoor est.)'
#  '$78K-$126K (Glassdoor est.)' '$116K-$194K (Glassdoor est.)'
#  '$83K-$133K (Glassdoor est.)' '$45K-$82K (Glassdoor est.)'
#  '$83K-$135K (Glassdoor est.)' '$70K-$122K (Glassdoor est.)'
#  '$70K-$132K (Glassdoor est.)' '$54K-$101K (Glassdoor est.)'
#  '$68K-$112K (Glassdoor est.)' '$42K-$74K (Glassdoor est.)'
#  '$95K-$161K (Glassdoor est.)' '$76K-$126K (Glassdoor est.)'
#  '$108K-$176K (Glassdoor est.)' '$130K-$208K (Glassdoor est.)'
#  '$37K-$68K (Glassdoor est.)' '$52K-$99K (Glassdoor est.)'
#  '$105K-$173K (Glassdoor est.)' '$71K-$134K (Glassdoor est.)'
#  '$39K-$82K (Glassdoor est.)' '$88K-$162K (Glassdoor est.)'
#  '$55K-$99K (Glassdoor est.)' '$67K-$117K (Glassdoor est.)'
#  '$92K-$150K (Glassdoor est.)' '$116K-$209K (Glassdoor est.)'
#  '$38K-$82K (Glassdoor est.)' 'Employer Provided Salary:$85K-$90K'
#  '$62K-$119K (Glassdoor est.)' '$84K-$136K (Glassdoor est.)'
#  '$52K-$89K (Glassdoor est.)' '$65K-$119K (Glassdoor est.)'
#  '$63K-$101K (Glassdoor est.)' '$127K-$202K (Glassdoor est.)'
#  '$31K-$57K (Glassdoor est.)' '$75K-$143K (Glassdoor est.)'
#  '$105K-$194K (Glassdoor est.)' '$45K-$86K (Glassdoor est.)'
#  '$95K-$154K (Glassdoor est.)' '$80K-$148K (Glassdoor est.)'
#  '$36K-$62K (Glassdoor est.)' '$50K-$92K (Glassdoor est.)'
#  '$67K-$135K (Glassdoor est.)' '$42K-$80K (Glassdoor est.)'
#  '$68K-$139K (Glassdoor est.)' '$34K-$92K (Glassdoor est.)'
#  '$54K-$71K (Glassdoor est.)' '$65K-$124K (Glassdoor est.)'
#  '$109K-$200K (Glassdoor est.)' '$61K-$113K (Glassdoor est.)'
#  '$43K-$86K (Glassdoor est.)' '$74K-$149K (Glassdoor est.)'
#  '$113K-$196K (Glassdoor est.)' '$97K-$160K (Glassdoor est.)'
#  '$24-$39 Per Hour(Glassdoor est.)' '$102K-$172K (Glassdoor est.)'
#  '$108K-$171K (Glassdoor est.)' '$76K-$142K (Glassdoor est.)'
#  '$202K-$306K (Glassdoor est.)' '$49K-$97K (Glassdoor est.)'
#  '$65K-$134K (Glassdoor est.)' '$32K-$59K (Glassdoor est.)'
#  '$87K-$158K (Glassdoor est.)' '$107K-$173K (Glassdoor est.)'
#  '$56K-$99K (Glassdoor est.)' 'Employer Provided Salary:$25-$28 Per Hour'
#  '$80K-$155K (Glassdoor est.)' '$43K-$98K (Glassdoor est.)'
#  '$45K-$78K (Glassdoor est.)' '$44K-$96K (Glassdoor est.)'
#  '$50K-$110K (Glassdoor est.)' '$61K-$119K (Glassdoor est.)'
#  'Employer Provided Salary:$100K-$140K' '$56K-$91K (Glassdoor est.)'
#  '$101K-$158K (Glassdoor est.)' '$125K-$210K (Glassdoor est.)'
#  '$43K-$77K (Glassdoor est.)' '$139K-$221K (Glassdoor est.)'
#  '$78K-$147K (Glassdoor est.)' '$37K-$66K (Glassdoor est.)'
#  '$38K-$64K (Glassdoor est.)' '$43K-$82K (Glassdoor est.)'
#  '$90K-$110K(Employer est.)' '$93K-$151K (Glassdoor est.)'
#  '$40K-$101K (Glassdoor est.)' '$97K-$180K (Glassdoor est.)'
#  '$81K-$134K (Glassdoor est.)' '$84K-$157K (Glassdoor est.)'
#  '$121K-$203K (Glassdoor est.)' '$52K-$85K (Glassdoor est.)'
#  '$81K-$140K (Glassdoor est.)' '$83K-$148K (Glassdoor est.)'
#  '$31K-$55K (Glassdoor est.)' '$102K-$178K (Glassdoor est.)'
#  'Employer Provided Salary:$110K-$130K' '$48K-$85K (Glassdoor est.)'
#  '$66K-$123K (Glassdoor est.)' '$92K-$146K (Glassdoor est.)'
#  '$21-$29 Per Hour(Glassdoor est.)' '$10-$17 Per Hour(Glassdoor est.)'
#  '$150K-$239K (Glassdoor est.)' '$52K-$91K (Glassdoor est.)'
#  '$82K-$129K(Employer est.)' '$47K-$101K (Glassdoor est.)'
#  '$49K-$76K (Glassdoor est.)' '$43K-$88K (Glassdoor est.)'
#  '$124K-$199K (Glassdoor est.)' '$97K-$181K (Glassdoor est.)'
#  '$100K-$173K (Glassdoor est.)' '$53K-$96K (Glassdoor est.)'
#  '$65K-$96K (Glassdoor est.)' '$75K-$127K (Glassdoor est.)'
#  '$94K-$139K (Glassdoor est.)' '$176K-$289K (Glassdoor est.)'
#  '$92K-$149K (Glassdoor est.)' '$118K-$188K (Glassdoor est.)'
#  '$108K-$146K (Glassdoor est.)' '$65K-$106K (Glassdoor est.)'
#  '$55K-$98K (Glassdoor est.)' '$94K-$162K (Glassdoor est.)'
#  '$63K-$120K (Glassdoor est.)' '$126K-$228K (Glassdoor est.)'
#  '$80K-$134K (Glassdoor est.)' '$85K-$142K (Glassdoor est.)'
#  '$87K-$140K (Glassdoor est.)' '$76K-$127K (Glassdoor est.)'
#  '$54K-$92K (Glassdoor est.)' '$61K-$100K (Glassdoor est.)'
#  '$112K-$179K (Glassdoor est.)' '$63K-$111K (Glassdoor est.)'
#  '$75K-$126K (Glassdoor est.)' '$110K-$184K (Glassdoor est.)'
#  '$76K-$145K (Glassdoor est.)' '$70K-$118K (Glassdoor est.)'
#  '$94K-$153K (Glassdoor est.)' '$150K-$180K (Glassdoor est.)'
#  '$42K-$77K (Glassdoor est.)' '$47K-$85K (Glassdoor est.)'
#  '$62K-$112K (Glassdoor est.)' '$64K-$108K (Glassdoor est.)'
#  '$89K-$144K (Glassdoor est.)' '$55K-$105K (Glassdoor est.)'
#  '$135K-$211K (Glassdoor est.)' '$57K-$80K (Glassdoor est.)'
#  '$129K-$215K (Glassdoor est.)' '$63K-$127K (Glassdoor est.)'
#  '$50K-$89K (Glassdoor est.)' '$71K-$124K (Glassdoor est.)'
#  '$69K-$121K (Glassdoor est.)' '$150K-$238K (Glassdoor est.)'
#  '$77K-$132K (Glassdoor est.)' '$59K-$112K (Glassdoor est.)'
#  '$35K-$65K (Glassdoor est.)' '$79K-$147K (Glassdoor est.)'
#  '$119K-$187K (Glassdoor est.)' '$90K-$157K (Glassdoor est.)'
#  '$32K-$62K (Glassdoor est.)' '$116K-$208K (Glassdoor est.)'
#  '$102K-$165K (Glassdoor est.)' '$91K-$159K (Glassdoor est.)'
#  '$80K-$133K (Glassdoor est.)' '$39K-$69K (Glassdoor est.)'
#  '$27K-$48K (Glassdoor est.)' '$36K-$71K (Glassdoor est.)'
#  '$130K-$206K (Glassdoor est.)' '$99K-$178K (Glassdoor est.)'
#  '$86K-$137K (Glassdoor est.)' '$37K-$100K (Glassdoor est.)'
#  '$58K-$111K (Glassdoor est.)' '$72K-$133K (Glassdoor est.)'
#  '$61K-$126K (Glassdoor est.)' '$95K-$160K (Glassdoor est.)'
#  '$33K-$61K (Glassdoor est.)' '$69K-$119K (Glassdoor est.)'
#  '$67K-$127K (Glassdoor est.)' '$66K-$117K (Glassdoor est.)'
#  '$50K-$98K (Glassdoor est.)' '$90K-$153K (Glassdoor est.)'
#  'Employer Provided Salary:$100K-$135K' '$42K-$79K (Glassdoor est.)'
#  '$84K-$153K (Glassdoor est.)' '$44K-$73K (Glassdoor est.)'
#  '$40K-$87K (Glassdoor est.)' '$72K-$142K (Glassdoor est.)'
#  '$74K-$137K (Glassdoor est.)' '$57K-$109K (Glassdoor est.)'
#  '$136K-$208K (Glassdoor est.)' '$171K-$272K (Glassdoor est.)'
#  '$65K-$126K (Glassdoor est.)' '$118K-$228K (Glassdoor est.)'
#  '$113K-$182K (Glassdoor est.)' '$58K-$104K (Glassdoor est.)'
#  '$58K-$108K (Glassdoor est.)' '$81K-$161K (Glassdoor est.)'
#  '$115K-$220K (Glassdoor est.)' '$71K-$144K (Glassdoor est.)'
#  '$32K-$57K (Glassdoor est.)' '$79K-$136K (Glassdoor est.)'
#  '$48K-$113K (Glassdoor est.)' '$27-$47 Per Hour(Glassdoor est.)'
#  '$68K-$125K (Glassdoor est.)' '$39K-$67K (Glassdoor est.)'
#  '$71K-$135K (Glassdoor est.)' '$61K-$123K (Glassdoor est.)'
#  '$87K-$141K (Glassdoor est.)' '$71K-$121K (Glassdoor est.)'
#  '$72K-$121K (Glassdoor est.)' '$51K-$88K (Glassdoor est.)'
#  '$101K-$141K (Glassdoor est.)' '$79K-$127K (Glassdoor est.)'
#  '$81K-$132K (Glassdoor est.)' 'Employer Provided Salary:$120K-$140K'
#  '$65K-$113K (Glassdoor est.)' '$59K-$125K (Glassdoor est.)'
#  '$80K-$142K (Glassdoor est.)' '$62K-$113K (Glassdoor est.)']

# %%
# Visualize salary distributions
fig, ax = plt.subplots(3, 1, figsize=(10, 15))

# Min Salary Distribution
ax[0].hist(df['min_salary'], bins=20, edgecolor='k', alpha=0.7)
ax[0].set_title('Minimum Salary Distribution')
ax[0].set_xlabel('Minimum Salary')
ax[0].set_ylabel('Frequency')

# Max Salary Distribution
ax[1].hist(df['max_salary'], bins=20, edgecolor='k', alpha=0.7)
ax[1].set_title('Maximum Salary Distribution')
ax[1].set_xlabel('Maximum Salary')
ax[1].set_ylabel('Frequency')

# Average Salary Distribution
ax[2].hist(df['avg_salary'], bins=20, edgecolor='k', alpha=0.7)
ax[2].set_title('Average Salary Distribution')
ax[2].set_xlabel('Average Salary')
ax[2].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# Boxplots for Salaries
fig, ax = plt.subplots(1, 3, figsize=(15, 5))

# Corrected Boxplots
sns.boxplot(y=df['min_salary'], ax=ax[0], color='skyblue')
ax[0].set_title('Minimum Salary Boxplot')

sns.boxplot(y=df['max_salary'], ax=ax[1], color='lightgreen')
ax[1].set_title('Maximum Salary Boxplot')

sns.boxplot(y=df['avg_salary'], ax=ax[2], color='salmon')
ax[2].set_title('Average Salary Boxplot')

plt.tight_layout()
plt.show()

# Scatter plot for Average Salary vs. Job Description Length
plt.figure(figsize=(8, 6))
plt.scatter(df['desc_len'], df['avg_salary'], alpha=0.6)
plt.title('Average Salary vs. Job Description Length')
plt.xlabel('Job Description Length')
plt.ylabel('Average Salary')
plt.grid(True)
plt.show()

# Boxplot for Average Salary by Skills
skills = ['python_yn', 'R_yn', 'spark', 'aws', 'excel']
fig, axes = plt.subplots(1, len(skills), figsize=(20, 5), sharey=True)

for i, skill in enumerate(skills):
    sns.boxplot(x=df[skill], y=df['avg_salary'], ax=axes[i])
    axes[i].set_title(f'Average Salary by {skill}')
    axes[i].set_xlabel(skill)
    axes[i].set_ylabel('')

fig.suptitle('Average Salary by Skills', fontsize=16)
plt.tight_layout()
plt.show()

# Scatter plot for Average Salary vs. Number of Competitors
plt.figure(figsize=(8, 6))
plt.scatter(df['num_comp'], df['avg_salary'], alpha=0.6)
plt.title('Average Salary vs. Number of Competitors')
plt.xlabel('Number of Competitors')
plt.ylabel('Average Salary')
plt.grid(True)
plt.show()

# %%
df['log_desc_len'] = np.log(df['desc_len']+ 1)
df['log_avg_salary'] = np.log(df['avg_salary'] + 1)

# Scatter plot for Log Average Salary vs. Log Job Description Length
plt.figure(figsize=(8, 6))
plt.scatter(df['log_desc_len'], df['log_avg_salary'], alpha=0.6, color='purple')
plt.title('Log Average Salary vs. Log Job Description Length')
plt.xlabel('Log Job Description Length')
plt.ylabel('Log Average Salary')
plt.grid(True)
plt.show()

# %%
job_titles = df['Job Title'].unique()
# Display the unique job titles
print("Unique Job Titles:")
for idx, title in enumerate(job_titles, start=1):
    print(f"{idx}. {title}")
# Out:
# Unique Job Titles:
# 1. Data Scientist
# 2. Healthcare Data Scientist
# 3. Research Scientist
# 4. Staff Data Scientist - Technology
# 5. Data Analyst
# 6. Data Engineer I
# 7. Scientist I/II, Biology
# 8. Customer Data Scientist
# 9. Data Scientist - Health Data Analytics
# 10. Senior Data Scientist / Machine Learning
# 11. Data Scientist - Quantitative
# 12. Digital Health Data Scientist
# 13. Associate Data Analyst
# 14. Clinical Data Scientist
# 15. Data Scientist / Machine Learning Expert
# 16. Web Data Analyst
# 17. Senior Data Scientist
# 18. Data Engineer
# 19. Data Scientist - Algorithms & Inference
# 20. Scientist
# 21. Lead Data Scientist
# 22. Spectral Scientist/Engineer
# 23. College Hire - Data Scientist - Open to December 2019 Graduates
# 24. Data Scientist, Office of Data Science
# 25. Data Science Analyst
# 26. Senior Risk Data Scientist
# 27. Data Scientist in Artificial Intelligence Early Career
# 28. Data Scientist - Research
# 29. R&D Data Analysis Scientist
# 30. Analytics Consultant
# 31. Director, Data Science
# 32. Data Scientist SR
# 33. R&D Sr Data Scientist
# 34. Customer Data Scientist/Sales Engineer (Bay
# 35. Jr. Business Data Analyst
# 36. Data Management Specialist
# 37. E-Commerce Data Analyst
# 38. Sr. Scientist II
# 39. Insurance Data Scientist
# 40. Data Modeler
# 41. Data Analyst / Scientist
# 42. Data Scientist, Rice University
# 43. Financial Data Analyst
# 44. Senior Data Analyst
# 45. Ag Data Scientist
# 46. Data Scientist II
# 47. Senior Data Engineer
# 48. Project Scientist
# 49. Data Analytics Manager
# 50. Senior Machine Learning (ML) Engineer / Data Scientist - Cyber Security Analytics
# 51. Associate Scientist
# 52. Scientist 2, QC Viral Vector
# 53. Machine Learning Engineer
# 54. Data Scientist/ML Engineer
# 55. Sr. Data Scientist
# 56. Data Engineer 4 - Contract
# 57. Data Analyst - Asset Management
# 58. Senior Research Scientist - Embedded System Development for DevOps
# 59. Data Scientist - Bioinformatics
# 60. Customer Data Scientist/Sales Engineer
# 61. MongoDB Data Engineer II
# 62. Senior Data Scientist Statistics
# 63. Senior Spark Engineer (Data Science)
# 64. BI & Platform Analytics Manager
# 65. Sr. Data Scientist - Analytics, Personalized Healthcare (PHC)
# 66. Pricipal Scientist Molecular and cellular biologist
# 67. Data Scientist (Actuary, FSA or ASA)
# 68. Staff Data Scientist
# 69. Data Engineer 5 - Contract (Remote)
# 70. Senior Scientist - Neuroscience
# 71. Medical Lab Scientist
# 72. Risk and Analytics IT, Data Scientist
# 73. Scientist, Analytical Development
# 74. Analytics Manager
# 75. Digital Marketing & ECommerce Data Analyst
# 76. Sr. Scientist - Digital & Image Analysis/Computational Pathology
# 77. Principal Scientist - Immunologist
# 78. Principal Data Scientist with over 10 years experience
# 79. MED TECH/LAB SCIENTIST - LABORATORY
# 80. Sr. Scientist, Quantitative Translational Sciences
# 81. Sr. Data Scientist II
# 82. Excel / VBA / SQL Data Analyst
# 83. Machine Learning Research Scientist
# 84. VP, Data Science
# 85. Radar Data Analyst
# 86. PL Actuarial-Lead Data Scientist
# 87. PV Scientist
# 88. Senior Data & Machine Learning Scientist
# 89. Principal Data Scientist (Computational Chemistry)
# 90. Principal Scientist, Chemistry & Immunology
# 91. Software Engineer - Data Visualization
# 92. Scientist/Senior Scientist, Autoimmune
# 93. Staff Machine Learning Engineer
# 94. Principal Scientist, Hematology
# 95. Lead Data Engineer
# 96. Marketing Data Analyst
# 97. Medical Laboratory Scientist
# 98. R&D Specialist/ Food Scientist
# 99. Senior Research Scientist-Machine Learning
# 100. Analytics Manager - Data Mart
# 101. Sr. Data Engineer - Contract-to-Hire (Java)
# 102. MED TECH/LAB SCIENTIST- SOUTH COASTAL LAB
# 103. Food Scientist - Developer
# 104. Staff Scientist-Downstream Process Development
# 105. Sr. Data Engineer
# 106. Senior Research Statistician- Data Scientist
# 107. Business Data Analyst, SQL
# 108. Medical Technologist / Clinical Laboratory Scientist
# 109. Associate Data Scientist/Computer Scientist
# 110. Business Intelligence Analyst / Developer
# 111. System and Data Analyst
# 112. Data & Analytics Consultant (NYC)
# 113. Big Data Engineer - Chicago - Future Opportunity
# 114. Survey Data Analyst
# 115. Lead Health Data Analyst - Front End
# 116. Junior Data Analyst
# 117. SQL Data Engineer
# 118. Sr. Data Scientist, Cyber-Security LT Contract
# 119. Insurance Financial Data Analyst
# 120. Data Engineer I - Azure
# 121. Information Security Data Analyst
# 122. Data Scientist, Senior
# 123. CONSULTANT– DATA ANALYTICS GROUP
# 124. Data Engineer, Data Engineering and Artifical Intelligence
# 125. Staff Scientist
# 126. Associate Scientist/Scientist, Process Analytical Technology - Small Molecule Analytical Chemistry
# 127. Sr. Data Analyst
# 128. Program/Data Analyst
# 129. Senior Data Scientist: Causal & Predictive analytics AI Innovation Lab
# 130. Principal Data Engineer, Data Platform & Insights
# 131. RESEARCH SCIENTIST - BIOLOGICAL SAFETY
# 132. Data Operations Lead
# 133. Big Data Engineer
# 134. Clinical Data Analyst
# 135. Computational Chemist/Data Scientist
# 136. Product Engineer – Data Science
# 137. Market Data Analyst
# 138. Staff Data Engineer
# 139. Associate Data Engineer
# 140. Staff BI and Data Engineer
# 141. Director - Data, Privacy and AI Governance
# 142. Scientist Manufacturing - Kentucky BioProcessing
# 143. Data Analytics Project Manager
# 144. Consultant - Analytics Consulting
# 145. Senior Scientist (Neuroscience)
# 146. Machine Learning Engineer - Regulatory
# 147. Scientist, Bacteriology
# 148. Associate Director, Platform and DevOps- Data Engineering and Aritifical Intelligence
# 149. Clinical Laboratory Scientist
# 150. Senior Data Scientist - R&D Oncology
# 151. Director II, Data Science - GRM Actuarial
# 152. Scientist, Molecular/Cellular Biologist
# 153. Scientist - Analytical Services
# 154. Associate Data Analyst- Graduate Development Program
# 155. Senior Insurance Data Scientist
# 156. Senior Data Science Systems Engineer
# 157. ENVIRONMENTAL ENGINEER/SCIENTIST
# 158. Senior Scientist - Regulatory Submissions
# 159. Scientist - Biomarker and Flow Cytometry
# 160. Revenue Analytics Manager
# 161. Associate Scientist, LC/MS Biologics
# 162. Sr. Scientist Method Development
# 163. IT - Data Engineer II
# 164. Research Scientist, Immunology - Cancer Biology
# 165. Project Scientist - Auton Lab, Robotics Institute
# 166. Enterprise Architect, Data
# 167. Senior Manager, Epidemiologic Data Scientist
# 168. Corporate Risk Data Analyst (SQL Based) - Milwaukee or
# 169. Marketing Data Analyst, May 2020 Undergrad
# 170. Data Modeler - Data Solutions Engineer
# 171. Associate Environmental Scientist - Wildlife Biologist
# 172. Associate, Data Science, Internal Audit
# 173. Sr Data Engineer (Sr BI Developer)
# 174. Senior LiDAR Data Scientist
# 175. Salesforce Analytics Consultant
# 176. Technology-Minded, Data Professional Opportunities
# 177. Managing Data Scientist/ML Engineer
# 178. Scientist, Pharmacometrics
# 179. Staff Scientist- Upstream PD
# 180. Scientist Manufacturing Pharma - Kentucky BioProcessing
# 181. Lead Big Data Engineer
# 182. Product Engineer – Spatial Data Science and Statistical Analysis
# 183. Sr Software Engineer (Data Scientist)
# 184. Sr. Data Engineer (ETL Developer)
# 185. Senior Data Scientist Artificial Intelligence
# 186. Analytics - Business Assurance Data Analyst
# 187. Associate Director/Director, Safety Scientist
# 188. Senior Scientist, Cell Pharmacology/Assay Development
# 189. Data Analyst Senior
# 190. Lead Data Engineer (Python)
# 191. Senior Data Scientist 4 Artificial Intelligence
# 192. Medical Lab Scientist - MLT
# 193. Senior Operations Data Analyst, Call Center Operations
# 194. Director II, Data Science - GRS Predictive Analytics
# 195. RESEARCH COMPUTER SCIENTIST - RESEARCH ENGINEER - SR. COMPUTER SCIENTIST - SOFTWARE DEVELOPMENT
# 196. Geospatial Software Developer and Data Scientist
# 197. Senior Scientist - Toxicologist - Product Integrity (Stewardship)
# 198. Systems Engineer II - Data Analyst
# 199. Senior Research Analytical Scientist-Non-Targeted Analysis
# 200. Director Data Science
# 201. Sr Data Analyst - IT
# 202. Associate Machine Learning Engineer / Data Scientist May 2020 Undergrad
# 203. Senior Scientist - Biostatistician
# 204. Principal Machine Learning Scientist
# 205. Data Analyst, Performance Partnership
# 206. Data Scientist Manager
# 207. Software Data Engineer - College
# 208. Senior Data Scientist - Algorithms
# 209. Senior Data Scientist Oncology
# 210. Principal Data Scientist
# 211. Data Scientist - Alpha Insights
# 212. Associate Principal Scientist, Pharmacogenomics
# 213. Data Scientist - Systems Engineering
# 214. Data Engineer - Consultant (Charlotte Based)
# 215. Data Analyst 1, full-time contract worker for up to 12 months
# 216. Scientist, Immuno-Oncology
# 217. Products Data Analyst II
# 218. Lead Data Analyst
# 219. Data Science Engineer - Mobile
# 220. Sr Expert Data Science, Advanced Visual Analytics (Associate level)
# 221. IT Associate Data Analyst
# 222. Business Data Analyst
# 223. Data Scientist - Sales
# 224. Principal, Data Science - Advanced Analytics
# 225. Data Science Project Manager
# 226. Sr Scientist, Immuno-Oncology - Oncology
# 227. Research Scientist – Security and Privacy
# 228. Data Science Manager
# 229. Data Analyst 2 (Missionary Department)
# 230. Supply Chain Data Analyst
# 231. Data Engineer - ETL
# 232. Data Modeler (Analytical Systems)
# 233. Data Scientist in Translational Medicine
# 234. Product Manager/Data Evangelist
# 235. Senior Data Scientist – Visualization, Novartis AI Innovation Lab
# 236. Senior Data Analyst/Scientist
# 237. Scientist – Cancer Discovery, Molecular Assay
# 238. Data Engineering Analyst
# 239. Manager of Data Science
# 240. Software Engineer (Data Scientist/Software Engineer) - SISW - MG
# 241. Associate Research Scientist I (Protein Expression and Production)
# 242. Director, Precision Medicine Clinical Biomarker Scientist
# 243. Senior Formulations Scientist II
# 244. Senior Quantitative Analyst
# 245. Research Scientist or Senior Research Scientist - Computer Vision
# 246. Data Analyst Chemist - Quality System Contractor
# 247. Research Scientist / Principal Research Scientist - Multiphysical Systems
# 248. Research Scientist, Machine Learning Department
# 249. Foundational Community Supports Data Analyst
# 250. Senior Health Data Analyst, Star Ratings
# 251. Principal Research Scientist/Team Lead, Medicinal Chemistry - Oncology
# 252. Senior Engineer, Data Management Engineering
# 253. Quality Control Scientist III- Analytical Development
# 254. Clinical Scientist, Clinical Development
# 255. Software Engineer Staff Scientist: Human Language Technologies
# 256. Manager, Safety Scientist, Medical Safety & Risk Management
# 257. Assistant Director/Director, Office of Data Science
# 258. Sr. Data Engineer | Big Data SaaS Pipeline
# 259. Scientist - CVRM Metabolism - in vivo pharmacology
# 260. Data Scientist (Warehouse Automation)
# 261. Jr. Data Scientist
# 262. Data Architect / Data Modeler
# 263. Associate Scientist / Sr. Associate Scientist, Antibody Discovery
# 264. Machine Learning Engineer (NLP)

# %%
job_title_column = 'Job Title'

# Define a function to group similar job titles
def categorize_job_title(title):
    title = str(title).lower()  # Convert to lowercase to standardize
    if re.search(r'data\s*scientist', title):
        return 'Data Scientist'
    elif re.search(r'data\s*analyst', title):
        return 'Data Analyst'
    elif re.search(r'machine\s*learning|ml\s*engineer', title):
        return 'Machine Learning Engineer'
    elif re.search(r'engineer', title):
        return 'Engineer'
    else:
        return 'Other'

# Apply the function to create a new column with grouped categories
df['Job Category'] = df[job_title_column].apply(categorize_job_title)

# Group and count the job categories
job_category_counts = df['Job Category'].value_counts()

# Display the results
print("Grouped Job Categories:")
print(job_category_counts)

# Plot the pie chart
plt.figure(figsize=(8, 8))  # Set the size of the pie chart
plt.pie(job_category_counts, labels=job_category_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Job Categories')  # Title for the pie chart
plt.show()
# Out:
# Grouped Job Categories:
# Job Category
# Data Scientist               279
# Other                        200
# Engineer                     142
# Data Analyst                  99
# Machine Learning Engineer     22
# Name: count, dtype: int64

# %%
# Find unique industries in the 'Industry' column
unique_industries = df['Industry'].dropna().unique()  # Drop missing values and get unique values

# Display unique industries
print("Unique Industries:")
for idx, industry in enumerate(unique_industries, start=1):
    print(f"{idx}. {industry}")

# Optional: Count the occurrences of each industry
industry_counts = df['Industry'].value_counts()

# Display industry counts
print("\nIndustry Counts:")
print(industry_counts)


# Plot the industry distribution as a pie chart
plt.figure(figsize=(10, 8))  # Set the figure size
plt.pie(industry_counts, labels=industry_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Industries')  # Add a title to the chart
plt.axis('equal')  # Ensure the pie chart is circular
plt.show()
# Out:
# Unique Industries:
# 1. Aerospace & Defense
# 2. Health Care Services & Hospitals
# 3. Security Services
# 4. Energy
# 5. Advertising & Marketing
# 6. Real Estate
# 7. Banks & Credit Unions
# 8. Consulting
# 9. Internet
# 10. Other Retail Stores
# 11. Research & Development
# 12. Department, Clothing, & Shoe Stores
# 13. Biotech & Pharmaceuticals
# 14. Motion Picture Production & Distribution
# 15. Enterprise Software & Network Solutions
# 16. Insurance Carriers
# 17. Insurance Agencies & Brokerages
# 18. Logistics & Supply Chain
# 19. Telecommunications Services
# 20. IT Services
# 21. Computer Hardware & Software
# 22. -1
# 23. Consumer Products Manufacturing
# 24. Industrial Manufacturing
# 25. Metals Brokers
# 26. Financial Transaction Processing
# 27. Sporting Goods Stores
# 28. Staffing & Outsourcing
# 29. Wholesale
# 30. Mining
# 31. Financial Analytics & Research
# 32. Federal Agencies
# 33. Education Training Services
# 34. Transportation Equipment Manufacturing
# 35. Farm Support Services
# 36. TV Broadcast & Cable Networks
# 37. Architectural & Engineering Services
# 38. Brokerage Services
# 39. Travel Agencies
# 40. Religious Organizations
# 41. Colleges & Universities
# 42. Investment Banking & Asset Management
# 43. Lending
# 44. Gambling
# 45. Food & Beverage Manufacturing
# 46. Gas Stations
# 47. Transportation Management
# 48. Video Games
# 49. Trucking
# 50. Social Assistance
# 51. Auctions & Galleries
# 52. K-12 Education
# 53. Telecommunications Manufacturing
# 54. Stock Exchanges
# 55. Construction
# 56. Accounting
# 57. Health Care Products Manufacturing
# 58. Health, Beauty, & Fitness
# 59. Consumer Product Rental
# 60. Beauty & Personal Accessories Stores
#
# Industry Counts:
# Industry
# Biotech & Pharmaceuticals                   112
# Insurance Carriers                           63
# Computer Hardware & Software                 59
# IT Services                                  50
# Health Care Services & Hospitals             49
# Enterprise Software & Network Solutions      42
# Internet                                     29
# Consulting                                   29
# Aerospace & Defense                          25
# Advertising & Marketing                      25
# Consumer Products Manufacturing              20
# Research & Development                       19
# Colleges & Universities                      16
# Energy                                       14
# Banks & Credit Unions                        12
# Federal Agencies                             11
# -1                                           10
# Staffing & Outsourcing                       10
# Travel Agencies                               8
# Lending                                       8
# Food & Beverage Manufacturing                 8
# Financial Analytics & Research                8
# Real Estate                                   8
# Security Services                             7
# Insurance Agencies & Brokerages               6
# Religious Organizations                       6
# Department, Clothing, & Shoe Stores           6
# Investment Banking & Asset Management         5
# Architectural & Engineering Services          4
# K-12 Education                                4
# Gas Stations                                  4
# Gambling                                      4
# Industrial Manufacturing                      4
# Telecommunications Services                   4
# Logistics & Supply Chain                      4
# Financial Transaction Processing              4
# Wholesale                                     3
# Stock Exchanges                               3
# Social Assistance                             3
# Construction                                  3
# Transportation Management                     3
# Video Games                                   3
# Education Training Services                   3
# Consumer Product Rental                       3
# Telecommunications Manufacturing              2
# Sporting Goods Stores                         2
# TV Broadcast & Cable Networks                 2
# Brokerage Services                            2
# Metals Brokers                                2
# Accounting                                    1
# Health Care Products Manufacturing            1
# Health, Beauty, & Fitness                     1
# Farm Support Services                         1
# Auctions & Galleries                          1
# Trucking                                      1
# Mining                                        1
# Other Retail Stores                           1
# Motion Picture Production & Distribution      1
# Transportation Equipment Manufacturing        1
# Beauty & Personal Accessories Stores          1
# Name: count, dtype: int64
